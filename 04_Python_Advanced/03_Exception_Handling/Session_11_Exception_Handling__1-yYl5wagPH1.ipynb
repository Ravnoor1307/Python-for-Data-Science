# %% [markdown]
# There are 2 stages where error may happen in a program
#
# - During compilation -> Syntax Error
# - During execution -> Exceptions

# %% [markdown]
# ### Syntax Error
#
# - Something in the program is not written according to the program grammar.
# - Error is raised by the interpreter/compiler
# - You can solve it by rectifying the program

# %% [markdown]
# ## 📖 Syntax Error — compile-time
#
# ```python
# print 'hello world'   # missing parentheses!
# ```
#
# - Compilation/material pe hoga — program chalti nahi, direct fail
# - Python interpreter ne uski grammar me galti pakad li
# - Fix: line phir se likho correct grammar se
# - Syntax errors debuggable hain — error message batata hai kaha

# %% [markdown]
# ## 🔬 Deep Dive : Syntax errors — compile time
#
# ```python
# print 'hello world'     # ❌ SyntaxError — missing ()
# a = 5
# if a==3                 # ❌ missing :
#     print('hello')
# iff a==3:               # ❌ typo keyword
# ```
#
# - **Syntax error** — parse time; Python code ko compile nahi kar pata
# - Program RUN bhi nahi hota — pehle parse fail
# - Causes: missing colon/parens, typo keywords, bad indentation
# - IndentationError — block wrong hua
# - Fix: correct syntax per Python rules
# - Highest priority — fix syntax first
# - Debug: error line+caret pointer
# - vs runtime exception — execute ke time error
# - Syntax = Gaali nahi, simple language rules

# %%
# Examples of syntax error
print 'hello world'
# Out:
#   File "<ipython-input-3-4655b84ba7b7>", line 2
#     print 'hello world'
#                       ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print('hello world')?

# %% [markdown]
# ### Other examples of syntax error
#
# - Leaving symbols like colon,brackets
# - Misspelling a keyword
# - Incorrect indentation
# - empty if/else/loops/class/functions

# %% [markdown]
# ## 📖 Syntax Error — missing colon etc.
#
# ```python
# a = 5
# if a == 3            # colon missing!
#     print('hello')   # indentation bhi galat
# ```
#
# - Colon bhoolna, bracket khol ke band na karna — syntax error
# - Keyword misspell (`iff`) — error
# - Indentation galat — Python block structure iska rule
# - Bache se pehle hi interpreter pakad leta hai

# %%
a = 5
if a==3
  print('hello')
# Out:
#   File "<ipython-input-68-efc58c10458d>", line 2
#     if a==3
#            ^
# SyntaxError: invalid syntax

# %%
a = 5
iff a==3:
  print('hello')
# Out:
#   File "<ipython-input-69-d1e6fae154d5>", line 2
#     iff a==3:
#         ^
# SyntaxError: invalid syntax

# %%
a = 5
if a==3:
print('hello')
# Out:
#   File "<ipython-input-70-ccc702dc036c>", line 3
#     print('hello')
#         ^
# IndentationError: expected an indented block

# %% [markdown]
# ## 📖 Common built-in exceptions
#
# Program chalti-chalti (runtime) bhi fail ho sakti hai. Ye common hain:
#
# | Exception | Jab hota hai |
# |---|---|
# | IndexError | Invalid index — `L[100]` |
# | KeyError | Dict me key nahi |
# | TypeError | Galat type ka operation |
# | ValueError | Galat value (int('a')) |
# | NameError | Name define hi nahi |
# | AttributeError | Object me attr nahi |
#
# ```python
# L = [1, 2, 3]
# L[100]       # IndexError
#
# d = {'name': 'nitish'}
# d['age']     # KeyError
#
# 1 + 'a'      # TypeError
# ```
#
# - Har error ka naam uski wajah batata hai — message padho
# - Inko handle karo `try/except` se (aage)

# %% [markdown]
# ## 🔬 Deep Dive : Common built-in exceptions
#
# | Exception | Kab aata |
# |---|---|
# | `IndexError` | list index out of range |
# | `ModuleNotFoundError` | import missing module |
# | `KeyError` | dict key nahi mila |
# | `TypeError` | wrong type op |
# | `ValueError` | value invalid for op |
# | `NameError` | variable not defined |
# | `AttributeError` | method/attr object pe nahi |
#
# ```python
# L = [1,2,3]; L[5]          # IndexError
# import nflib                # ModuleNotFoundError
# d = {}; d['x']              # KeyError
# '5' + 5                     # TypeError
# int('abc')                  # ValueError
# print(x)                    # NameError
# L.upper()                   # AttributeError
# ```
#
# - Har exception → progress stops + stack trace
# - Learn to READ error messages — root cause window
# - Specific exception names for catching
# - Exceptions inherit BaseException/Exception hierarchy
# - Some can't catch gracefully — still handle
# - ZeroDivisionError, FileNotFoundError common too
# - Traceback: bottom line = actual error

# %%
# IndexError
# The IndexError is thrown when trying to access an item at an invalid index.
L = [1,2,3]
L[100]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-71-c90668d2b194> in <module>
#       2 # The IndexError is thrown when trying to access an item at an invalid index.
#       3 L = [1,2,3]
# ----> 4 L[100]
#
# IndexError: list index out of range

# %%
# ModuleNotFoundError
# The ModuleNotFoundError is thrown when a module could not be found.
import mathi
math.floor(5.3)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-73-cbdaf00191df> in <module>
#       1 # ModuleNotFoundError
#       2 # The ModuleNotFoundError is thrown when a module could not be found.
# ----> 3 import mathi
#       4 math.floor(5.3)
#
# ModuleNotFoundError: No module named 'mathi'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# KeyError
# The KeyError is thrown when a key is not found

d = {'name':'nitish'}
d['age']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-74-453afa1c9765> in <module>
#       3
#       4 d = {'name':'nitish'}
# ----> 5 d['age']
#
# KeyError: 'age'

# %%
# TypeError
# The TypeError is thrown when an operation or function is applied to an object of an inappropriate type.
1 + 'a'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-2a3eb3f5bb0a> in <module>
#       1 # TypeError
#       2 # The TypeError is thrown when an operation or function is applied to an object of an inappropriate type.
# ----> 3 1 + 'a'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# ValueError
# The ValueError is thrown when a function's argument is of an inappropriate type.
int('a')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-e419d2a084b4> in <module>
#       1 # ValueError
#       2 # The ValueError is thrown when a function's argument is of an inappropriate type.
# ----> 3 int('a')
#
# ValueError: invalid literal for int() with base 10: 'a'

# %%
# NameError
# The NameError is thrown when an object could not be found.
print(k)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-79-e3e8aaa4ec45> in <module>
#       1 # NameError
#       2 # The NameError is thrown when an object could not be found.
# ----> 3 print(k)
#
# NameError: name 'k' is not defined

# %%
# AttributeError
L = [1,2,3]
L.upper()

# Stacktrace
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-80-dd5a29625ddc> in <module>
#       1 # AttributeError
#       2 L = [1,2,3]
# ----> 3 L.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %% [markdown]
# ### Exceptions
#
# If things go wrong during the execution of the program(runtime). It generally happens when something unforeseen has happened.
#
# - Exceptions are raised by python runtime
# - You have to takle is on the fly
#
# #### **Examples**
#
# - Memory overflow
# - Divide by 0 -> logical error
# - Database error

# %% [markdown]
# ## 📖 Why handle exceptions?
#
# ```python
# try:
#     with open('sample1.txt', 'r') as f:
#         print(f.read())
# except:
#     print('sorry file not found')
# ```
#
# - Bina handle program crash hoga — user ko ugly error
# - `try/except` — risky code try me, fallback except me
# - Exception handler block me hai wo pata chalta hai
# - Program gracefully continue kar sakta hai

# %% [markdown]
# ## 🔬 Deep Dive : try / except — why handle
#
# ```python
# try:
#     with open('sample1.txt', 'r') as f:
#         print(f.read())
# except FileNotFoundError:
#     print('File nahi mili, handle kiya!')
# ```
#
# - Without handle: FileNotFoundError → program CRASH
# - With try/except: error catch → graceful flow
# - User ko friendly message, program continues
# - Multi except order: specific → general
# - Multiple: `except (A, B):` combined
# - Catch-all `except Exception:` broad (last resort)
# - Blocked: bare except bad practice
# - `as e` → error object: `except ValueError as e: print(e)`
# - try me baki code skip after exception
# - Data validation, file ops, API calls — handling hugs

# %%
# Why is it important to handle exceptions
# how to handle exceptions
# -> Try except block

# %%
# let's create a file
with open('sample.txt','w') as f:
  f.write('hello world')

# %%
# try catch demo
try:
  with open('sample1.txt','r') as f:
    print(f.read())
except:
  print('sorry file not found')
# Out:
# sorry file not found

# %% [markdown]
# ## 📖 Catching specific exception
#
# ```python
# try:
#     m = 5
#     f = open('sample1.txt', 'r')    # could raise FileNotFoundError
#     print(f.read())
#     print(5 / 0)                    # could raise ZeroDivisionError
# except FileNotFoundError:
#     print('file nahi mili')
# except Exception as e:
#     print('kuch aur hua:', e)
# ```
#
# - Multiple `except` blocks — har exception ka specific handler
# - `except FileNotFoundError:` — particular class catch
# - `except Exception as e:` — baaki sab (catch-all, last me)
# - Order: specific pehle, generic baad me

# %%
# catching specific exception
try:
  m=5
  f = open('sample1.txt','r')
  print(f.read())
  print(m)
  print(5/2)
  L = [1,2,3]
  L[100]
except FileNotFoundError:
  print('file not found')
except NameError:
  print('variable not defined')
except ZeroDivisionError:
  print("can't divide by 0")
except Exception as e:
  print(e)
# Out:
# [Errno 2] No such file or directory: 'sample1.txt'

# %%
# else
try:
  f = open('sample1.txt','r')
except FileNotFoundError:
  print('file nai mili')
except Exception:
  print('kuch to lafda hai')
else:
  print(f.read())
# Out:
# file nai mili

# %% [markdown]
# ## 📖 else & finally
#
# ```python
# try:
#     f = open('sample1.txt', 'r')
# except FileNotFoundError:
#     print('file nai mili')     # exceptional path
# else:
#     print(f.read())            # no error → else chalega
# finally:
#     print('ye to print hoga hi')   # hamesha chalta hai
# ```
#
# - `else` — jab try me **error nahi** aaya tabhi chalta hai
# - `finally` — hamesha chalta hai (error aaye ya na aaye)
# - Use-case: files, connections, resources `finally` me close karo
# - `raise` karoge to `finally` phir bhi chalega

# %% [markdown]
# ## 🔬 Deep Dive : else & finally
#
# ```python
# try:
#     f = open('sample1.txt', 'r')
# except FileNotFoundError:
#     print('File missing')
# else:
#     print('File mili! No error')   # sirf try success pe
# finally:
#     print('Hamesha chalega')       # exception ya no — guaranteed
# ```
#
# - `else` — tabhi when try NO exception
# - `finally` — ALWAYS runs (even return/raise!)
# - finally resource cleanup: close file, release lock
# - Order: try → (except) → else → finally
# - return inside try → finally STILL runs
# - Common: with-close manual, DB close
# - finally guarantee by language semantics
# - raise inside except → finally still execute
# - else valuable: code jo only-on-success (no swallow)

# %%
# finally
# else
try:
  f = open('sample1.txt','r')
except FileNotFoundError:
  print('file nai mili')
except Exception:
  print('kuch to lafda hai')
else:
  print(f.read())
finally:
  print('ye to print hoga hi')
# Out:
# file nai mili
# ye to print hoga hi

# %% [markdown]
# ## 📖 raise — manually error
#
# ```python
# raise ZeroDivisionError('aise hi try kar raha hu')
# ```
#
# - Errors automatic bhi aate hain, `raise` se **khud bhi** uphaar sakte ho
# - Use-case: invalid input, business rule violate
# - Raise karne par exception handler me jaata hai
# - Java me `throw` == Python me `raise` (except == catch)

# %%
# raise Exception
# In Python programming, exceptions are raised when errors occur at runtime. 
# We can also manually raise exceptions using the raise keyword.

# We can optionally pass values to the exception to clarify why that exception was raised

# %% [markdown]
# ## 🔬 Deep Dive : raise — manual exception
#
# ```python
# raise ZeroDivisionError('aise hi try kar raha hu')
# ```
#
# - `raise Exception('message')` — khud error THROW karo
# - Kab: invalid state detect karke — fail fast
# - Custom business rules: not enough balance, wrong age
# - Raise inside try → caught by except
# - Common raises: `raise ValueError('invalid input')`
# - raise with args → str(e) shows message
# - Can raise non-Exception? BaseException exists but anti-pattern
# - Re-raise: `raise` inside except (propagate)
# - 'raise Exception' generic — prefer specific
# - Java-style: checked vs unchecked — Python sab unchecked

# %%
raise ZeroDivisionError('aise hi try kar raha hu')
# Java
# try -> try
# except -> catch
# raise -> throw
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-106-5a07d7d89433> in <module>
# ----> 1 raise ZeroDivisionError('aise hi try kar raha hu')
#
# ZeroDivisionError: aise hi try kar raha hu

# %%
class Bank:

  def __init__(self,balance):
    self.balance = balance

  def withdraw(self,amount):
    if amount < 0:
      raise Exception('amount cannot be -ve')
    if self.balance < amount:
      raise Exception('paise nai hai tere paas')
    self.balance = self.balance - amount

obj = Bank(10000)
try:
  obj.withdraw(15000)
except Exception as e:
  print(e)
else:
  print(obj.balance)
# Out:
# paise nai hai tere paas

# %% [markdown]
# ## 🔬 Deep Dive : Custom exceptions
#
# ```python
# class MyException(Exception):
#     def __init__(self, message):
#         super().__init__(message)
#
# raise MyException('custom error')     # niche catch kar le
# ```
#
# - **Custom exception** = class inheriting Exception
# - Allow domain-specific errors (BankError, AuthError)
# - Clearer than generic
# - `__init__` passes message
# - Catch by custom name:
# ```python
# try:
#     raise MyException('x')
# except MyException as e:
#     print(e)
# ```
# - Hierarchy: BusinessException → InsufficientFundsException
# - Code: raise custom where condition fails
# - Libraries define custom exceptions
# - Exception hierarchy check: `__mro__`
# - Keep small: naming + message

# %%
class MyException(Exception):
  def __init__(self,message):
    print(message)

class Bank:

  def __init__(self,balance):
    self.balance = balance

  def withdraw(self,amount):
    if amount < 0:
      raise MyException('amount cannot be -ve')
    if self.balance < amount:
      raise MyException('paise nai hai tere paas')
    self.balance = self.balance - amount

obj = Bank(10000)
try:
  obj.withdraw(5000)
except MyException as e:
  pass
else:
  print(obj.balance)
# Out:
# 5000

# %% [markdown]
# ## 📖 Custom exceptions
#
# ```python
# class MyException(Exception):
#     def __init__(self, message):
#         print(message)
# ```
#
# - `Exception` ko inherit karake apni error class banao
# - `__init__` me message, custom behavior
# - `raise MyException('something wrong')` — specific domain errors
# - Better debugging: naam hi bata dega kya hua

# %%
# creating custom exceptions
# exception hierarchy in python

# %% [markdown]
# ## 📖 Real scenario: bank withdraw
#
# ```python
# class Bank:
#     def __init__(self, balance):
#         self.balance = balance
#
#     def withdraw(self, amount):
#         if amount > self.balance:
#             raise MyException('Not enough balance!')
#         else:
#             self.balance -= amount
# ```
#
# - Business rule violate → custom exception raise
# - `Bank.withdraw` me balance check, raise se user ko bataya
# - Calling side `try/except MyException` — graceful message
# - Ye popular pattern: domain-specific errors, clean flow

# %% [markdown]
# ## 🔬 Deep Dive : Real scenario — bank withdraw
#
# ```python
# class Bank:
#     def __init__(self, balance):
#         self.balance = balance
#     def withdraw(self, amt):
#         if amt > self.balance:
#             raise ValueError('Insufficient funds')   # custom rule
#         self.balance -= amt
#         print('Withdrawn', amt)
# ```
#
# - Business logic me exception raise karna = validation
# - withdraw amt > balance → raise, avoid negative balance
# - Data integrity protection
# - Caller decide handling: try/except or propagate
# - Real apps: many rules → custom exception types
# - vs return error code: exceptions are explicit
# - Contract: methods document raising conditions
# - OOP + Exception combine — cleaner code
# - Log meaningful messages — debugging aid

# %%
# simple example

# %% [markdown]
# ## 📖 Exception hierarchy
#
# ```
# BaseException
#  └── Exception
#       ├── ArithmeticError
#       ├── LookupError (IndexError, KeyError...)
#       ├── FileNotFoundError
#       └── your custom classes
# ```
#
# - Saare exceptions `BaseException` → `Exception` ke andar
# - Catch-all `except Exception` — almost sab pakad leta hai (not
#   KeyboardInterrupt/SystemExit)
# - Custom exception `Exception` ko inherit karti hai
# - `class ... (Exception)` — hierarchy me apna position

# %% [markdown]
# ## 🔬 Deep Dive : Exception hierarchy
#
# ```python
# BaseException
#  ├── Exception                # user exceptions base
#  │    ├── ArithmeticError
#  │    │    └── ZeroDivisionError
#  │    ├── LookupError
#  │    │    ├── IndexError
#  │    │    └── KeyError
#  │    ├── ValueError
#  │    ├── TypeError
#  │    └── MyCustomError       # yours
#  ├── KeyboardInterrupt        # 🔥 (not subclass of Exception!)
#  └── SystemExit
# ```
#
# - BaseException root — Exception common parent
# - Catch `except Exception` → catches user erra but NOT KeyboardInterrupt/SystemExit
# - Custom: subclass Exception (clean)
# - Hierarchy helps: catch parent catches children
# - Order: specific (child) FIRST, generic after
# - `except Exception as e` introspection
# - MRO: `MyException.__mro__`
# - Docs: full tree in builtins help('builtins')/Types
# - Knowing parents = knowing what except catches

# %%
class SecurityError(Exception):

  def __init__(self,message):
    print(message)

  def logout(self):
    print('logout')

class Google:

  def __init__(self,name,email,password,device):
    self.name = name
    self.email = email
    self.password = password
    self.device = device

  def login(self,email,password,device):
    if device != self.device:
      raise SecurityError('bhai teri to lag gayi')
    if email == self.email and password == self.password:
      print('welcome')
    else:
      print('login error')



obj = Google('nitish','nitish@gmail.com','1234','android')

try:
  obj.login('nitish@gmail.com','1234','windows')
except SecurityError as e:
  e.logout()
else:
  print(obj.name)
finally:
  print('database connection closed')
# Out:
# bhai teri to lag gayi
# logout
# database connection closed
